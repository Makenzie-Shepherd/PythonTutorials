# %% [markdown]
# Plotting Relational Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mdff = pd.read_csv("datasets/008TutorialDataFile1.csv")
display(mdff)
# Out:
#              X           Y
# 0     0.100000  274.608664
# 1     0.310553  235.391417
# 2     0.521106  241.092965
# 3     0.731658  264.568801
# 4     0.942211  197.304517
# ..         ...         ...
# 195  41.157789  458.805412
# 196  41.368342  419.435665
# 197  41.578894  423.102998
# 198  41.789447  444.141966
# 199  42.000000  433.947337
#
# [200 rows x 2 columns]

# %%
mdff.plot(x='X', y='Y', kind='scatter', color='r')
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %% [markdown]
# Plot shows a relationship

# %% [markdown]
# y = a + bx + err

# %% [markdown]
# a : y-intercept; b : slope; err : error/variability

# %%
sns.set_theme() #set theme to seaborn's default
sns.relplot(data=mdff, x='X', y='Y')

# %%
sns.lmplot(data=mdff, x='X', y='Y') #plots a fitted line to the data aka a 'linear model'

# %% [markdown]
# Takeaways: there is a relationship between x and y & the random variability limits our ability to predict any one particular y value to a given x value

# %%
myfit = np.polyfit(x=mdff['X'], y=mdff['Y'], deg=1) #estimates the slope and y-intercept
print(myfit)
# Out:
# [  4.50987413 242.13206112]

# %%
sns.residplot(data=mdff, x='X', y='Y') #plots the residuals
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %%
fitvals = np.polyval(myfit, mdff['X'])

# %%
myres = mdff['Y'] - fitvals

# %%
sns.displot(myres, kind='kde')

# %%
np.std(myres) #standard deviation
# Out:
# 98.0014577098805

# %% [markdown]
# Line of Fit: y = 4.5x + 242 + N(0, 36)

# %% [markdown]
# Second Data Set

# %%
mdff = pd.read_csv("datasets/008TutorialDataFile2.csv")
display(mdff)
# Out:
#            X         Y
# 0   3.353062  2.453846
# 1   4.871934  1.586254
# 2   6.220546  1.626260
# 3   4.086313  2.001541
# 4   4.806622  2.138675
# ..       ...       ...
# 95  3.966096  1.685230
# 96  6.706995  2.422260
# 97  5.650075  2.224024
# 98  5.077873  1.706203
# 99  5.962620  2.408682
#
# [100 rows x 2 columns]

# %%
sns.relplot(data=mdff, x='X', y='Y') #plot the relationship

# %%
sns.lmplot(data=mdff, x='X', y='Y')

# %%
sns.scatterplot(data=mdff, x='X', y='Y')
sns.rugplot(data=mdff, x='X', y='Y') #rugs/interior tick marks showing the position of each data point
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %%
sns.jointplot(data=mdff, x='X', y='Y') #shows the individual distributions of the two variables

# %%
sns.jointplot(data=mdff, x='X', y='Y', kind='reg')

# %% [markdown]
# Third Data Set

# %%
mdff = pd.read_csv("datasets/008TutorialDataFile3.csv")
display(mdff)
# Out:
#              X            Y
# 0     0.100000   -42.297551
# 1     0.310553   151.497704
# 2     0.521106    68.200382
# 3     0.731658    71.047752
# 4     0.942211   -89.430861
# ..         ...          ...
# 195  41.157789  1063.004451
# 196  41.368342  1036.558676
# 197  41.578894  1198.886853
# 198  41.789447  1147.630694
# 199  42.000000  1237.778334
#
# [200 rows x 2 columns]

# %%
sns.relplot(data=mdff, x='X', y='Y')

# %%
sns.lmplot(data=mdff, x='X', y='Y')

# %%
sns.residplot(data=mdff, x='X', y='Y')
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %% [markdown]
# Graphs shows a pattern to the residuals. The reason it the model is a second order polynomial: y = a + bx + cx^2 + N(0,1)

# %%
sns.lmplot(data=mdff, x='X', y='Y', order=2)

# %%
g = sns.residplot(data=mdff, x='X', y='Y', order=2)

# %%
myfit = np.polyfit(x=mdff['X'], y=mdff['Y'], deg=2)
print(myfit)
# Out:
# [0.6987571  0.01960354 7.26458072]

# %%
fitvals = np.polyval(myfit, mdff['X'])
myres = mdff['Y'] - fitvals
sns.displot(myres)

# %%
np.std(myres)
# Out:
# 98.0014577098805

# %% [markdown]
# y = 7.3 + 0.02x + 0.7x^2 + N(0,98)
